# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  index      company   body-style  \
# 0           0             0               0      0  alfa-romero  convertible
# 1           1             1               1      1  alfa-romero  convertible
# 2           2             2               2      2  alfa-romero    hatchback
# 3           3             3               3      3         audi        sedan
# 4           4             4               4      4         audi        sedan
#
#    wheel-base  length engine-type num-of-cylinders  horsepower  \
# 0        88.6   168.8        dohc             four         111
# 1        88.6   168.8        dohc             four         111
# 2        94.5   171.2        ohcv              six         154
# 3        99.8   176.6         ohc             four         102
# 4        99.4   176.6         ohc             five         115
#
#    average-mileage    price
# 0               21  13495.0
# 1               21  16500.0
# 2               19  16500.0
# ...

# %%
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)
df.to_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  index        company  \
# 0            0             0               0      0    alfa-romero
# 1            1             1               1      1    alfa-romero
# 2            2             2               2      2    alfa-romero
# 3            3             3               3      3           audi
# 4            4             4               4      4           audi
# 5            5             5               5      5           audi
# 6            6             6               6      6           audi
# 7            7             7               7      9            bmw
# 8            8             8               8     10            bmw
# 9            9             9               9     11            bmw
# 10          10            10              10     13            bmw
# 11          11            11              11     14            bmw
# 12          12            12              12     15            bmw
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  index company  \
# 48          48            48              48                48     66  toyota
# 49          49            49              49                49     67  toyota
# 50          50            50              50                50     68  toyota
# 51          51            51              51                51     69  toyota
# 52          52            52              52                52     70  toyota
# 53          53            53              53                53     71  toyota
# 54          54            54              54                54     79  toyota
#
#    body-style  wheel-base  length engine-type num-of-cylinders  horsepower  \
# 48  hatchback        95.7   158.7         ohc             four          62
# 49  hatchback        95.7   158.7         ohc             four          62
# 50  hatchback        95.7   158.7         ohc             four          62
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# audi             4
# mitsubishi       4
# mercedes-benz    4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# jaguar           3
# porsche          3
# honda            3
# isuzu            3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers['company','price'].max()
priceDf
# Out:
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['company','average-mileage'].mean()
mileageDf
# Out:
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
import pandas as pd
carsDf = pd.read_csv("C:\\Users\\Dang Dung\\Downloads\\Python code\\Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(5)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  index  \
# 35          35            35              35                35     47
# 11          11            11              11                11     14
# 34          34            34              34                34     46
# 46          46            46              46                46     62
# 12          12            12              12                12     15
#
#           company   body-style  wheel-base  length engine-type  \
# 35  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11            bmw        sedan       103.5   193.8         ohc
# 34  mercedes-benz        sedan       120.9   208.1        ohcv
# 46        porsche  convertible        89.5   168.9        ohcf
# 12            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# ...

# %%
import pandas as pd
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)
carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
import pandas as pd
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)
carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
